# %% [markdown]
# # Data Ingestion

# %%
! pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Check local current path

import os
print(os.getcwd())
# Out:
# c:\Users\Aden Sakata\Desktop\EduThemes\methodAnalysis\Data_Handling

# %%
import pandas as pd

df = pd.read_excel('sample_data.xlsx', engine='openpyxl')
df
# Out:
#     If any, what do you see as the key benefits or opportunities for using AI chatbots in educational settings?  \
# 0             Greater availability for online students
# 1         Easily obtained and accessible information.
# 2    Easier access to sources or relevant informati...
# 3    if they work, helping give examples or providi...
# 4    It gives students concise answers that may hav...
# ..                                                 ...
# 256  Organization, editing, and allocation of resou...
# 257  They can be helpful in the editing process for...
# 258                         Writing and memory support
# 259  Students need to learn how to guide chatbots t...
# 260  It is beneficial when used correctly, suggesti...
#
#                                    recoding - viktoria  \
# 0                                      access to info
# 1                                      access to info
# 2                                      access to info
# ...

# %%
# Rename first, second, and third columns for ease in analysis
df.rename(columns={
    df.columns[0]: 'User_Input',
    df.columns[1]: 'Label_1',
    df.columns[2]: 'Label_2'
    }, inplace=True)

df = df[['User_Input', 'Label_1', 'Label_2']]
df
# Out:
# C:\Users\Aden Sakata\AppData\Local\Temp\ipykernel_21956\2917137294.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={
#                                             User_Input  \
# 0             Greater availability for online students
# 1         Easily obtained and accessible information.
# 2    Easier access to sources or relevant informati...
# 3    if they work, helping give examples or providi...
# 4    It gives students concise answers that may hav...
# ..                                                 ...
# 256  Organization, editing, and allocation of resou...
# 257  They can be helpful in the editing process for...
# 258                         Writing and memory support
# 259  Students need to learn how to guide chatbots t...
# ...

# %%
df.head()
# Out:
#                                           User_Input          Label_1  \
# 0           Greater availability for online students  access to info
# 1       Easily obtained and accessible information.   access to info
# 2  Easier access to sources or relevant informati...  access to info
# 3  if they work, helping give examples or providi...  access to info
# 4  It gives students concise answers that may hav...  access to info
#
#            Label_2
# 0  access to info
# 1  access to info
# 2  access to info
# 3  access to info
# 4  access to info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_Input  257 non-null    object
#  1   Label_1     261 non-null    object
#  2   Label_2     261 non-null    object
# dtypes: object(3)
# memory usage: 6.2+ KB

# %%
df.describe()
# Out:
#        User_Input                             Label_1  \
# count         257                                 261
# unique        255                                  43
# top         None.  teaching, feedback & study support
# freq            2                                  30
#
#                                    Label_2
# count                                  261
# unique                                  43
# top     teaching, feedback & study support
# freq                                    30

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Evaluate Data Quality

# %%
# Check for missing values (NaN)
print('Missing Values:\n', df[['User_Input', 'Label_1', 'Label_2']].isnull().sum())

# Check for empty strings
print('Empty Strings:\n', (df[['User_Input', 'Label_1', 'Label_2']] == '').sum())
# Out:
# Missing Values:
#  User_Input    1
# Label_1       0
# Label_2       0
# dtype: int64
# Empty Strings:
#  User_Input    0
# Label_1       0
# Label_2       0
# dtype: int64

# %%
# Check length of user responses

df['User_Input_Length'] = df['User_Input'].apply(lambda x: len(x.split()) if isinstance(x, str) else 0)
print("User_Input length stats:\n", df['User_Input_Length'].describe())
# Out:
# User_Input length stats:
#  count    256.000000
# mean      16.894531
# std       17.769345
# min        0.000000
# 25%        5.000000
# 50%       12.000000
# 75%       23.250000
# max      135.000000
# Name: User_Input_Length, dtype: float64

# %%
# Check label_1 distribution

print('Label_1 counts:\n', df['Label_1'].value_counts())
# Out:
# Label_1 counts:
#  Label_1
# teaching, feedback & study support                                                     30
# access to info                                                                         26
# feedback & study support                                                               22
# speeds up work                                                                         20
# teaching                                                                               17
# no benefit                                                                             17
# access to info, teaching, feedback & study support                                     14
# starting point                                                                         14
# access to info, speeds up work                                                         13
# other                                                                                  13
# ...

# %%
# Check label_2 distribution 

print('Label_2 counts:\n', df['Label_2'].value_counts())
# Out:
# Label_2 counts:
#  Label_2
# teaching, feedback & study support                                                     30
# access to info                                                                         26
# feedback & study support                                                               22
# speeds up work                                                                         20
# teaching                                                                               17
# no benefit                                                                             17
# access to info, teaching, feedback & study support                                     14
# starting point                                                                         14
# access to info, speeds up work                                                         13
# other                                                                                  13
# ...

# %% [markdown]
# # Data Transformation

# %%
# Code Implemented Later

# %% [markdown]
# # Validation / Exploration
